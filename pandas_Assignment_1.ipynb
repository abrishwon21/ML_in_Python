# %% [markdown]
# <a href="https://colab.research.google.com/github/abrishwon21/ML_in_Python/blob/master/pandas_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#homework
import pandas as pd
import numpy as np

#Q1.group the pokemon on the basis of their type and then display their details
# by taking the pokemon name from the users
pokemon=pd.read_csv("/content/sample_data/Pokemon.csv")
TypesOfPokemon=pokemon.groupby(['Type1'])
#without taking input from users

for n,group in TypesOfPokemon:
  print(n)
  print(group)
# Out:
# Bug
#        #        Name Type1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 13    10    Caterpie   Bug     NaN  ...       20     45           1      False
# 14    11     Metapod   Bug     NaN  ...       25     30           1      False
# 15    12  Butterfree   Bug  Flying  ...       80     70           1      False
# 16    13      Weedle   Bug  Poison  ...       20     50           1      False
# 17    14      Kakuna   Bug  Poison  ...       25     35           1      False
# ..   ...         ...   ...     ...  ...      ...    ...         ...        ...
# 698  637   Volcarona   Bug    Fire  ...      105    100           5      False
# 717  649    Genesect   Bug   Steel  ...       95     99           5      False
# 732  664  Scatterbug   Bug     NaN  ...       25     35           6      False
# 733  665      Spewpa   Bug     NaN  ...       30     29           6      False
# 734  666    Vivillon   Bug  Flying  ...       50     89           6      False
#
# ...

# %%
#by taking the pokemon name from the users
pokType=input("please enter the pokemon type ")
print("The ",pokType," pokemons are the following:")
TypesOfPokemon.get_group(pokType)
# Out:
# please enter the pokemon type Water
# The  Water  pokemons are the following:
#        #                     Name  Type1  ... Speed  Generation  Legendary
# 9      7                 Squirtle  Water  ...    43           1      False
# 10     8                Wartortle  Water  ...    58           1      False
# 11     9                Blastoise  Water  ...    78           1      False
# 12     9  BlastoiseMega Blastoise  Water  ...    78           1      False
# 59    54                  Psyduck  Water  ...    55           1      False
# ..   ...                      ...    ...  ...   ...         ...        ...
# 724  656                  Froakie  Water  ...    71           6      False
# 725  657                Frogadier  Water  ...    97           6      False
# 726  658                 Greninja  Water  ...   122           6      False
# 762  692                Clauncher  Water  ...    44           6      False
# ...

# %%
#Q2.Find most powerfull pokemon on the basis of total.
'''
Note: if the pokemons are have the same total,then their legendary will be seen or considered
'''
TypesOfPokemon.describe()
# Out:
#               #                                 ... Generation
#           count        mean         std    min  ...        25%  50%   75%  max
# Type1                                           ...
# Bug        69.0  334.492754  210.445160   10.0  ...       2.00  3.0  5.00  6.0
# Dark       31.0  461.354839  176.022072  197.0  ...       3.00  5.0  5.00  6.0
# Dragon     32.0  474.375000  170.190169  147.0  ...       3.00  4.0  5.00  6.0
# Electric   44.0  363.500000  202.731063   25.0  ...       2.00  4.0  4.25  6.0
# Fairy      17.0  449.529412  271.983942   35.0  ...       2.00  6.0  6.00  6.0
# Fighting   27.0  363.851852  218.565200   56.0  ...       1.50  3.0  5.00  6.0
# Fire       52.0  327.403846  226.262840    4.0  ...       1.00  3.0  5.00  6.0
# Flying      4.0  677.750000   42.437209  641.0  ...       5.00  5.5  6.00  6.0
# Ghost      32.0  486.500000  209.189218   92.0  ...       3.00  4.0  6.00  6.0
# ...

# %%
pwrfulPok=pd.DataFrame(pokemon.groupby('Type1')['Total'].max())

print("The winners are the following:")
print("Top 5 pokemon Types on the basis of their total")
topPokem=pwrfulPok.index.to_list()
print(topPokem[:10])
# Out:
# The winners are the following:
# Top 5 pokemon Types on the basis of their total
# ['Bug', 'Dark', 'Dragon', 'Electric', 'Fairy', 'Fighting', 'Fire', 'Flying', 'Ghost', 'Grass']
